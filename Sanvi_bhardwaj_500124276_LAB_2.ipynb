# %% [markdown]
# <a href="https://colab.research.google.com/github/sanvibhardwaj/algorithm_lab_3rd_sem-500124276-/blob/main/Sanvi_bhardwaj_500124276_LAB_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('diabetes.csv.zip')

# %%
data.head()
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0        82  56.0    3.6    4.3  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9    4.4  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2    4.6  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5    4.6  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9    7.7  Buckingham   64    male    68.0
#
#    ...   frame  bp.1s  bp.1d  bp.2s  bp.2d  waist   hip  time.ppn  \
# 0  ...  medium  118.0   59.0    NaN    NaN   29.0  38.0     720.0
# 1  ...   large  112.0   68.0    NaN    NaN   46.0  48.0     360.0
# 2  ...   large  190.0   92.0  185.0   92.0   49.0  57.0     180.0
# 3  ...   large  110.0   50.0    NaN    NaN   33.0  38.0     480.0
# 4  ...  medium  138.0   80.0    NaN    NaN   44.0  41.0     300.0
#
#       diagnosis result
# 0  Non-Diabetic    0.0
# 1  Non-Diabetic    0.0
# 2  Non-Diabetic    0.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         403 non-null    int64
#  1   chol       402 non-null    float64
#  2   stab.glu   403 non-null    int64
#  3   hdl        402 non-null    float64
#  4   ratio      402 non-null    float64
#  5   glyhb      390 non-null    float64
#  6   location   403 non-null    object
#  7   age        403 non-null    int64
#  8   gender     403 non-null    object
#  9   height     398 non-null    float64
#  10  weight     402 non-null    float64
#  11  frame      403 non-null    object
#  12  bp.1s      398 non-null    float64
#  13  bp.1d      398 non-null    float64
#  14  bp.2s      141 non-null    float64
#  15  bp.2d      141 non-null    float64
#  16  waist      401 non-null    float64
#  17  hip        401 non-null    float64
#  18  time.ppn   400 non-null    float64
# ...

# %%
data.isnull().sum()
# Out:
# id             0
# chol           1
# stab.glu       0
# hdl            1
# ratio          1
# glyhb         13
# location       0
# age            0
# gender         0
# height         5
# weight         1
# frame          0
# bp.1s          5
# bp.1d          5
# bp.2s        262
# bp.2d        262
# waist          2
# hip            2
# time.ppn       3
# diagnosis     13
# result        13
# dtype: int64

# %%
data.dropna()
# Out:
#         id   chol  stab.glu    hdl  ratio  glyhb    location  age  gender  \
# 2     1002  228.0        92   37.0    6.2    4.6  Buckingham   58  female
# 6     1011  195.0        92   41.0    4.8    4.8  Buckingham   30    male
# 8     1016  177.0        87   49.0    3.6    4.8  Buckingham   45    male
# 10    1024  242.0        82   54.0    4.5    4.8      Louisa   60  female
# 15    1036  213.0        83   47.0    4.5    3.4      Louisa   33  female
# ..     ...    ...       ...    ...    ...    ...         ...  ...     ...
# 394  41254  169.0       104   58.0    2.9    4.8      Louisa   25  female
# 395  41500  179.0        85   50.0    3.6    5.0      Louisa   37    male
# 397  41503  301.0        90  118.0    2.6    4.3      Louisa   89  female
# 398  41506  296.0       369   46.0    6.4   16.1      Louisa   53    male
# 399  41507  284.0        89   54.0    5.3    4.4      Louisa   51  female
#
#      height  ...   frame  bp.1s  bp.1d  bp.2s  bp.2d  waist   hip  time.ppn  \
# ...

# %%
numerical_columns = data.select_dtypes(include=['float']).columns

# %%
numerical_columns
# Out:
# Index(['chol', 'hdl', 'ratio', 'glyhb', 'height', 'weight', 'bp.1s', 'bp.1d',
#        'bp.2s', 'bp.2d', 'waist', 'hip', 'time.ppn', 'result'],
#       dtype='object')

# %%
for column in numerical_columns:
  plt.figure(figsize=(8, 6))
  sns.histplot(data[column], kde=True) # Change 'true' to 'True'
  plt.title(f"histogram of {column}")
  plt.xlabel(column)
  plt.ylabel("frequency")
  plt.show()

# %%
print(numerical_columns)
# Out:
# Index(['chol', 'hdl', 'ratio', 'glyhb', 'height', 'weight', 'bp.1s', 'bp.1d',
#        'bp.2s', 'bp.2d', 'waist', 'hip', 'time.ppn', 'result'],
#       dtype='object')

# %%
if len(numerical_columns) >= 2:
  plt.figure(figsize=(6, 4))
  sns.scatterplot(data = data, x=numerical_columns[3], y=numerical_columns[2] )
  plt.title(f"scatter plot : {numerical_columns[3]} vs { numerical_columns[2]}")
  plt.xlabel(numerical_columns[3]) # Corrected from plt.xlable to plt.xlabel
  plt.ylabel(numerical_columns[2]) # Corrected from plt.xlable to plt.ylabel
  plt.show()

# %%
weight = data['weight']
cholesterol = data['chol']

plt.figure(figsize=(8, 6))
sns.scatterplot(x=weight, y=cholesterol, color='skyblue')
plt.title('graph plotted between weight and Cholesterol', fontsize=14)
plt.xlabel('weight', fontsize=12)
plt.ylabel('Cholesterol', fontsize=12)
plt.grid(True, alpha=0.5)

plt.legend()
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-27-b7e81e0d6136>:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
from scipy.stats import zscore

# %%
data = data.fillna(0)
# Replace 'ID' with 'id' to match the actual column name in your dataframe
data['z_score'] = zscore(data['id'])

# %%
data['z_score']
# Out:
# 0     -1.262248
# 1     -1.262164
# 2     -1.262080
# 3     -1.261996
# 4     -1.261827
#          ...
# 398    2.151263
# 399    2.151347
# 400    2.151600
# 401    2.171994
# 402    2.172331
# Name: z_score, Length: 403, dtype: float64
